# %% [raw]
# ---
# title: My notebook
# description: Notebook with plot
# params:
#     name:
#         input: text
#         label: What is your name?
#         value: Piotr
#     points:
#         input: slider
#         label: How many points?
#         value: 200
#         min: 10
#         max: 250
# ---

# %%
import random
from matplotlib import pyplot as plt

# %%
name = "Piotr"
points = 200

# %%
print(f"Hello {name}!")
# Out:
# Hello Piotr!

# %%
plt.figure(figsize=(10, 7))
x = [random.gauss(0, 1) for _ in range(points)]
y = [random.gauss(0, 1) for _ in range(points)]
_=plt.plot(x, y, '.', markersize=14)
